# %% [markdown]
# <a href="https://colab.research.google.com/github/brenosyperrek/pandas_IO/blob/main/Pandas_OI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Criando os Nomes

# %%
import pandas as pd

# %%
nomes_f = pd.read_json('https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?sexo=f')
nomes_m = pd.read_json('https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?sexo=m')

# %%
nomes_f.sample(5)
# Out:
#          nome  regiao     freq  rank sexo
# 14    JESSICA       0   456472    15    F
# 1         ANA       0  3079729     2    F
# 2   FRANCISCA       0   721637     3    F
# 11     CAMILA       0   469851    12    F
# 7    FERNANDA       0   531607     8    F

# %%
nomes_m.sample(5)
# Out:
#          nome  regiao     freq  rank sexo
# 19    RODRIGO       0   598825    20    M
# 3   FRANCISCO       0  1765197     4    M
# 7       LUCAS       0  1116818     8    M
# 1        JOAO       0  2971935     2    M
# 11    GABRIEL       0   922744    12    M

# %%
print('Quantidade de nomes: ' + str(len(nomes_f) + len(nomes_m)))
# Out:
# Quantidade de nomes: 40

# %%
frames = [nomes_f, nomes_m]

# %%
nomes = pd.concat(frames)['nome'].to_frame()

# %%
nomes.head()
# Out:
#         nome
# 0      MARIA
# 1        ANA
# 2  FRANCISCA
# 3    ANTONIA
# 4    ADRIANA

# %%
nomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nome    40 non-null     object
# dtypes: object(1)
# memory usage: 640.0+ bytes

# %% [markdown]
# # Incluindo ID dos alunos

# %%
import numpy as np
np.random.seed(123)

# %%
total_alunos = len(nomes)
total_alunos
# Out:
# 40

# %%
nomes['id_aluno'] = np.random.permutation(total_alunos) + 1

# %%
nomes.head()
# Out:
#         nome  id_aluno
# 0      MARIA         7
# 1        ANA        11
# 2  FRANCISCA        13
# 3    ANTONIA        39
# 4    ADRIANA         6

# %%
dominios = ['@dominiodoemail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)
nomes.head()
# Out:
#         nome  id_aluno                 dominio
# 0      MARIA         7     @servicodoemail.com
# 1        ANA        11  @dominiodoemail.com.br
# 2  FRANCISCA        13  @dominiodoemail.com.br
# 3    ANTONIA        39     @servicodoemail.com
# 4    ADRIANA         6  @dominiodoemail.com.br

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()
nomes
# Out:
#          nome  id_aluno                 dominio  \
# 0       MARIA         7     @servicodoemail.com
# 1         ANA        11  @dominiodoemail.com.br
# 2   FRANCISCA        13  @dominiodoemail.com.br
# 3     ANTONIA        39     @servicodoemail.com
# 4     ADRIANA         6  @dominiodoemail.com.br
# 5     JULIANA        12     @servicodoemail.com
# 6      MARCIA        24  @dominiodoemail.com.br
# 7    FERNANDA         2  @dominiodoemail.com.br
# 8    PATRICIA        14     @servicodoemail.com
# 9       ALINE        21  @dominiodoemail.com.br
# 10     SANDRA         9     @servicodoemail.com
# 11     CAMILA        38  @dominiodoemail.com.br
# 12     AMANDA        25     @servicodoemail.com
# 13      BRUNA         8  @dominiodoemail.com.br
# 14    JESSICA        19  @dominiodoemail.com.br
# 15    LETICIA        40  @dominiodoemail.com.br
# 16      JULIA         4  @dominiodoemail.com.br
# 17    LUCIANA        32     @servicodoemail.com
# ...

# %% [markdown]
# # Criando a tabela Cursos

# %%
# !pip3 install html5lib
# !pip3 install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
type(cursos)
# Out:
# list

# %%
cursos = cursos[0]

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos.head()
# Out:
#            Nome do curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
cursos = cursos.rename(columns={'Nome do curso':'nome_do_curso'})
cursos.head()
# Out:
#            nome_do_curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
cursos['id'] = cursos.index + 1
cursos.head()
# Out:
#            nome_do_curso  id
# 0  Lógica de programação   1
# 1          Java para Web   2
# 2            C# para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %%
cursos = cursos.set_index('id')
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %% [markdown]
# # Matriculando os alunos nos cursos

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                        email
# 0     MARIA         7     @servicodoemail.com     maria@servicodoemail.com
# 5   JULIANA        12     @servicodoemail.com   juliana@servicodoemail.com
# 10   SANDRA         9     @servicodoemail.com    sandra@servicodoemail.com
# 14  MARCELO        23     @servicodoemail.com   marcelo@servicodoemail.com
# 13    BRUNA         8  @dominiodoemail.com.br  bruna@dominiodoemail.com.br

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size = total_alunos) * 1.5).astype(int)

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                          email  \
# 11  GABRIEL        37  @dominiodoemail.com.br  gabriel@dominiodoemail.com.br
# 4   ADRIANA         6  @dominiodoemail.com.br  adriana@dominiodoemail.com.br
# 0     MARIA         7     @servicodoemail.com       maria@servicodoemail.com
# 8      LUIZ        10     @servicodoemail.com        luiz@servicodoemail.com
# 12   AMANDA        25     @servicodoemail.com      amanda@servicodoemail.com
#
#     matriculas
# 11           1
# 4            2
# 0            4
# 8            1
# 12           1

# %%
nomes.matriculas.describe()
# Out:
# count    40.000000
# mean      1.900000
# std       1.428645
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.000000
# max       9.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.displot(nomes.matriculas)

# %%
nomes.matriculas.value_counts()
# Out:
# 1    19
# 2    14
# 3     4
# 4     2
# 9     1
# Name: matriculas, dtype: int64

# %% [markdown]
# # Selecionando cursos

# %%
nomes.sample(3)
# Out:
#        nome  id_aluno                 dominio                          email  \
# 5     PAULO        28  @dominiodoemail.com.br    paulo@dominiodoemail.com.br
# 12   AMANDA        25     @servicodoemail.com      amanda@servicodoemail.com
# 18  VANESSA        22  @dominiodoemail.com.br  vanessa@dominiodoemail.com.br
#
#     matriculas
# 5            1
# 12           1
# 18           1

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
  id = row.id_aluno
  matriculas = row.matriculas
  for i in range(matriculas):
    mat = [id,np.random.choice(cursos.index, p = prob)]
    todas_matriculas.append(mat)

matriculas = pd.DataFrame(todas_matriculas, columns=['id_aluno', 'id_curso'])

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0         7        18
# 1         7        15
# 2         7        12
# 3         7        13
# 4        11        10

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns={'id_aluno':'quantidade_alunos'})
matriculas_por_curso.head()
# Out:
#           quantidade_alunos          nome_do_curso
# id_curso
# 1                         2  Lógica de programação
# 2                         2          Java para Web
# 3                         1            C# para Web
# 4                         1          Ruby on Rails
# 5                         5       Cursos de Python

# %% [markdown]
# # Saída em diferentes formatos

# %%
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index=False)

# %%
matriculas_json = matriculas_por_curso.to_json()
matriculas_json
# Out:
# '{"quantidade_alunos":{"1":2,"2":2,"3":1,"4":1,"5":5,"6":2,"7":2,"8":1,"9":10,"10":7,"12":7,"13":9,"14":1,"15":10,"16":2,"17":3,"18":5,"19":1,"20":5},"nome_do_curso":{"1":"L\\u00f3gica de programa\\u00e7\\u00e3o","2":"Java para Web","3":"C# para Web","4":"Ruby on Rails","5":"Cursos de Python","6":"PHP com MySql","7":".NET para web","8":"Novas integra\\u00e7\\u00f5es com Java","9":"TDD com Java","10":"C\\u00f3digo limpo com C#","12":"Hardware b\\u00e1sico","13":"Persist\\u00eancia com .NET","14":"Desenvolvendo jogos","15":"An\\u00e1lise de dados","16":"Estat\\u00edstica b\\u00e1sica","17":"Internet das coisas","18":"Programa\\u00e7\\u00e3o funcional","19":"Boas pr\\u00e1ticas em Java","20":"Orienta\\u00e7\\u00e3o objetos com Java"}}'

# %%
matriculas_hrml = matriculas_por_curso.to_html()
matriculas_hrml
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>quantidade_alunos</th>\n      <th>nome_do_curso</th>\n    </tr>\n    <tr>\n      <th>id_curso</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>2</td>\n      <td>Lógica de programação</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>Java para Web</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>1</td>\n      <td>C# para Web</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>1</td>\n      <td>Ruby on Rails</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>5</td>\n      <td>Cursos de Python</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>2</td>\n      <td>PHP com MySql</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>2</td>\n      <td>.NET para web</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>1</td>\n      <td>Novas integrações com Java</td>\n    </tr>
# ...

# %%
print(matriculas_hrml)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>quantidade_alunos</th>
#       <th>nome_do_curso</th>
#     </tr>
#     <tr>
#       <th>id_curso</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Lógica de programação</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>Java para Web</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>C# para Web</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>Ruby on Rails</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>Cursos de Python</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2</td>
#       <td>PHP com MySql</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2</td>
#       <td>.NET para web</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1</td>
# ...

# %% [markdown]
# # Criando banco SQL

# %%
# !pip install sqlalchemy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sqlalchemy import create_engine, MetaData, Table

# %%
engine = create_engine('sqlite:///:memory:')

# %%
engine
# Out:
# Engine(sqlite:///:memory:)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
matriculas_por_curso.to_sql('matriculas', engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Buscando do banco SQL

# %%
query = 'select * from matriculas where quantidade_alunos < 6'

# %%
pd.read_sql(query, engine)
# Out:
#     id_curso  quantidade_alunos                nome_do_curso
# 0          1                  2        Lógica de programação
# 1          2                  2                Java para Web
# 2          3                  1                  C# para Web
# 3          4                  1                Ruby on Rails
# 4          5                  5             Cursos de Python
# 5          6                  2                PHP com MySql
# 6          7                  2                .NET para web
# 7          8                  1   Novas integrações com Java
# 8         14                  1          Desenvolvendo jogos
# 9         16                  2           Estatística básica
# 10        17                  3          Internet das coisas
# 11        18                  5        Programação funcional
# 12        19                  1        Boas práticas em Java
# 13        20                  5  Orientação objetos com Java

# %%
pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_alunos'])
# Out:
#                   nome_do_curso  quantidade_alunos
# 0         Lógica de programação                  2
# 1                 Java para Web                  2
# 2                   C# para Web                  1
# 3                 Ruby on Rails                  1
# 4              Cursos de Python                  5
# 5                 PHP com MySql                  2
# 6                 .NET para web                  2
# 7    Novas integrações com Java                  1
# 8                  TDD com Java                 10
# 9           Código limpo com C#                  7
# 10              Hardware básico                  7
# 11        Persistência com .NET                  9
# 12          Desenvolvendo jogos                  1
# 13             Análise de dados                 10
# 14           Estatística básica                  2
# 15          Internet das coisas                  3
# 16        Programação funcional                  5
# ...

# %%
muitas_matriculas = pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_alunos'])

# %%
muitas_matriculas.query('quantidade_alunos > 5')
# Out:
#             nome_do_curso  quantidade_alunos
# 8            TDD com Java                 10
# 9     Código limpo com C#                  7
# 10        Hardware básico                  7
# 11  Persistência com .NET                  9
# 13       Análise de dados                 10

# %% [markdown]
# #Escrevendo no banco

# %%
muitas_matriculas.to_sql('muitas_matriculas', con=engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas', 'muitas_matriculas']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Nomes dos Alunos/Alunos da próxima turma

# %%
matriculas_por_curso.head(3)
# Out:
#           quantidade_alunos          nome_do_curso
# id_curso
# 1                         2  Lógica de programação
# 2                         2          Java para Web
# 3                         1            C# para Web

# %%
matriculas.head(3)
# Out:
#    id_aluno  id_curso
# 0         7        18
# 1         7        15
# 2         7        12

# %%
id_curso = 16
proxima_turma = matriculas.query('id_curso == {}'.format(id_curso))
proxima_turma
# Out:
#     id_aluno  id_curso
# 13        24        16
# 70        18        16

# %%
nomes.head(3)
# Out:
#         nome  id_aluno                 dominio  \
# 0      MARIA         7     @servicodoemail.com
# 1        ANA        11  @dominiodoemail.com.br
# 2  FRANCISCA        13  @dominiodoemail.com.br
#
#                              email  matriculas
# 0         maria@servicodoemail.com           4
# 1        ana@dominiodoemail.com.br           2
# 2  francisca@dominiodoemail.com.br           2

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))
# Out:
#           id_curso     nome                 dominio  \
# id_aluno
# 24              16   MARCIA  @dominiodoemail.com.br
# 18              16  EDUARDO     @servicodoemail.com
#
#                                  email  matriculas
# id_aluno
# 24        marcia@dominiodoemail.com.br           1
# 18          eduardo@servicodoemail.com           2

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome']
# Out:
# id_aluno
# 24     MARCIA
# 18    EDUARDO
# Name: nome, dtype: object

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome'].to_frame()
# Out:
#              nome
# id_aluno
# 24         MARCIA
# 18        EDUARDO

# %%
nome_curso = cursos.loc[id_curso]
nome_curso
# Out:
# nome_do_curso    Estatística básica
# Name: 16, dtype: object

# %%
nome_curso = nome_curso.nome_do_curso
nome_curso
# Out:
# 'Estatística básica'

# %%
proxima_turma = proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome'].to_frame()
proxima_turma
# Out:
#              nome
# id_aluno
# 24         MARCIA
# 18        EDUARDO

# %%
proxima_turma = proxima_turma.rename(columns = {'nome' : 'Alunos do curso de {}'.format(nome_curso)})
proxima_turma
# Out:
#          Alunos do curso de Estatística básica
# id_aluno
# 24                                      MARCIA
# 18                                     EDUARDO

# %% [markdown]
# # Exportar para Excel

# %%
proxima_turma.to_excel('proxima_turma.xlsx', index=False)

# %%
pd.read_excel('proxima_turma.xlsx')
# Out:
#   Alunos do curso de Estatística básica
# 0                                MARCIA
# 1                               EDUARDO
